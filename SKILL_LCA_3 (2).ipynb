# %% [markdown]
# Step 1: Loading and Exploring the BoT-IoT Dataset

# %%
import pandas as pd

# Load the datasets
df1 = pd.read_csv('/content/reduced_data_1[1].csv')
df2 = pd.read_csv('/content/reduced_data_2[1].csv')
df3 = pd.read_csv('/content/reduced_data_3[1].csv')
df4 = pd.read_csv('/content/reduced_data_4[1].csv')
print("DataFrame 1 shape:", df1.shape)
print("DataFrame 2 shape:", df2.shape)
print("DataFrame 3 shape:", df2.shape)
print("DataFrame 4 shape:", df4.shape)

display(df1.head())
display(df2.head())
display(df3.head())
display(df4.head())
# Out:
# <ipython-input-2-54626487f70f>:4: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('/content/reduced_data_1[1].csv')
# <ipython-input-2-54626487f70f>:5: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('/content/reduced_data_2[1].csv')
# <ipython-input-2-54626487f70f>:6: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('/content/reduced_data_3[1].csv')
# <ipython-input-2-54626487f70f>:7: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv('/content/reduced_data_4[1].csv')
# DataFrame 1 shape: (1000000, 46)
# DataFrame 2 shape: (1000000, 46)
# DataFrame 3 shape: (1000000, 46)
# DataFrame 4 shape: (668522, 46)
#    pkSeqID         stime flgs  flgs_number proto  proto_number  \
# ...

# %%
# Merge datasets
merged_df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# Drop missing values and duplicates
merged_df.dropna(inplace=True)
merged_df.drop_duplicates(inplace=True)
merged_df.reset_index(drop=True, inplace=True)

# %%
# Encode categorical columns
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

categorical_cols = merged_df.select_dtypes(include=['object']).columns.tolist()
if categorical_cols:
    le = LabelEncoder()
    for col in categorical_cols:
        merged_df[col] = le.fit_transform(merged_df[col].astype(str))

# %%
# Normalize numeric columns
numeric_cols = merged_df.select_dtypes(include=['int64', 'float64']).columns.tolist()
scaler = MinMaxScaler()
merged_df[numeric_cols] = scaler.fit_transform(merged_df[numeric_cols])
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel

# %%
# Embedded Feature Selection using L1-based Logistic Regression
# Assuming 'attack' is the target variable
X = merged_df.drop('attack', axis=1)
y = merged_df['attack']

# Logistic Regression with L1 regularization
model = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000)
model.fit(X, y)
# Out:
# LogisticRegression(max_iter=1000, penalty='l1', solver='liblinear')

# %%
# Select features
selector = SelectFromModel(model, prefit=True)
X_embedded = selector.transform(X)

# Get selected feature names
selected_features = X.columns[selector.get_support()]
print(" Selected Features using Embedded Technique (L1):", list(selected_features))
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
#  Selected Features using Embedded Technique (L1): ['pkSeqID', 'stime', 'flgs', 'proto', 'daddr', 'state', 'ltime', 'TnP_PerProto', 'N_IN_Conn_P_DstIP', 'category', 'subcategory']

# %%
# Create DataFrame with selected features for classification
X_selected_df = pd.DataFrame(X_embedded, columns=selected_features)
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
from sklearn.linear_model import LogisticRegression
import warnings
warnings.filterwarnings("ignore")

# %%
# Split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X_selected_df, y, test_size=0.3, random_state=42)

# %% [markdown]
# Step 2: Merging and Cleaning the Dataset

# %%
merged_df = pd.concat([df1, df2, df3, df4], ignore_index=True)
print("Merged DataFrame shape:", merged_df.shape)
display(merged_df.head())

print("\nMissing values before:")
print(merged_df.isnull().sum())
merged_df.dropna(inplace=True)

print("\nMissing values after handling:")
print(merged_df.isnull().sum())
# Out:
# Merged DataFrame shape: (3668522, 46)
#    pkSeqID         stime flgs  flgs_number proto  proto_number  \
# 0        1  1.528089e+09    e            1   tcp             1
# 1        2  1.528089e+09    e            1   arp             2
# 2        3  1.528089e+09    e            1   tcp             1
# 3        4  1.528089e+09    e            1   tcp             1
# 4        5  1.528089e+09    e            1   tcp             1
#
#              saddr  sport            daddr dport  ...  AR_P_Proto_P_DstIP  \
# 0  192.168.100.147  49960    192.168.100.7    80  ...             1.12704
# 1    192.168.100.7     -1  192.168.100.147    -1  ...         15267.20000
# 2  192.168.100.147  49962    192.168.100.7    80  ...             1.12704
# 3  192.168.100.147  49964    192.168.100.7    80  ...             1.12704
# 4  192.168.100.147  49966    192.168.100.7    80  ...             1.12704
#
#    N_IN_Conn_P_DstIP N_IN_Conn_P_SrcIP  AR_P_Proto_P_Sport  \
# ...

# %% [markdown]
# Step 3: Data Cleaning – Removing Duplicates and Finalizing Preprocessing

# %%
merged_df.info()

merged_df.drop_duplicates(inplace=True)

merged_df.reset_index(drop=True, inplace=True)

print("\nFinal Preprocessed DataFrame shape:", merged_df.shape)
display(merged_df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3668522 entries, 0 to 3668521
# Data columns (total 46 columns):
#  #   Column                            Dtype
# ---  ------                            -----
#  0   pkSeqID                           int64
#  1   stime                             float64
#  2   flgs                              object
#  3   flgs_number                       int64
#  4   proto                             object
#  5   proto_number                      int64
#  6   saddr                             object
#  7   sport                             object
#  8   daddr                             object
#  9   dport                             object
#  10  pkts                              int64
#  11  bytes                             int64
#  12  state                             object
#  13  state_number                      int64
#  14  ltime                             float64
#  15  seq                               int64
# ...

# %% [markdown]
# Step 4 & 5: Encoding Categorical Features and Normalizing Numeric Data

# %%
# 4. Encode categorical columns
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
categorical_cols = merged_df.select_dtypes(include=['object']).columns.tolist()
print("Categorical Columns:", categorical_cols)

print(merged_df.dtypes) # Reason why there is no output for categorical columns

if categorical_cols:
    le = LabelEncoder()
    for col in categorical_cols:
        merged_df[col] = le.fit_transform(merged_df[col].astype(str))

# 5. Normalize numeric columns using Min-Max Scaler
numeric_cols = merged_df.select_dtypes(include=['int64', 'float64']).columns.tolist()
print("Numeric Columns:", numeric_cols)

scaler = MinMaxScaler()
merged_df[numeric_cols] = scaler.fit_transform(merged_df[numeric_cols])

# Final output
print("\nFinal Preprocessed & Normalized DataFrame :", merged_df.shape)
display(merged_df.head())
# Out:
# Categorical Columns: ['flgs', 'proto', 'saddr', 'sport', 'daddr', 'dport', 'state', 'category', 'subcategory']
# pkSeqID                               int64
# stime                               float64
# flgs                                 object
# flgs_number                           int64
# proto                                object
# proto_number                          int64
# saddr                                object
# sport                                object
# daddr                                object
# dport                                object
# pkts                                  int64
# bytes                                 int64
# state                                object
# state_number                          int64
# ltime                               float64
# seq                                   int64
# dur                                 float64
# mean                                float64
# stddev                              float64
# ...

# %% [markdown]
# Step 6: Exploratory Data Analysis – Correlation Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
corr_matrix = merged_df.corr(numeric_only=True)

# Plot the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True)
plt.title("Correlation Heatmap of Features", fontsize=16)
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
print("Columns in merged_df:", merged_df.columns.tolist())
# Out:
# Columns in merged_df: ['pkSeqID', 'stime', 'flgs', 'flgs_number', 'proto', 'proto_number', 'saddr', 'sport', 'daddr', 'dport', 'pkts', 'bytes', 'state', 'state_number', 'ltime', 'seq', 'dur', 'mean', 'stddev', 'sum', 'min', 'max', 'spkts', 'dpkts', 'sbytes', 'dbytes', 'rate', 'srate', 'drate', 'TnBPSrcIP', 'TnBPDstIP', 'TnP_PSrcIP', 'TnP_PDstIP', 'TnP_PerProto', 'TnP_Per_Dport', 'AR_P_Proto_P_SrcIP', 'AR_P_Proto_P_DstIP', 'N_IN_Conn_P_DstIP', 'N_IN_Conn_P_SrcIP', 'AR_P_Proto_P_Sport', 'AR_P_Proto_P_Dport', 'Pkts_P_State_P_Protocol_P_DestIP', 'Pkts_P_State_P_Protocol_P_SrcIP', 'attack', 'category', 'subcategory']

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel

# Load the datasets
df1 = pd.read_csv('/content/reduced_data_1[1].csv')
df2 = pd.read_csv('/content/reduced_data_2[1].csv')
df3 = pd.read_csv('/content/reduced_data_3[1].csv')
df4 = pd.read_csv('/content/reduced_data_4[1].csv')

# Merge datasets
merged_df = pd.concat([df1, df2, df3, df4], ignore_index=True)

# Drop missing values and duplicates
merged_df.dropna(inplace=True)
merged_df.drop_duplicates(inplace=True)
merged_df.reset_index(drop=True, inplace=True)

# Encode categorical columns
categorical_cols = merged_df.select_dtypes(include=['object']).columns.tolist()
if categorical_cols:
    le = LabelEncoder()
    for col in categorical_cols:
        merged_df[col] = le.fit_transform(merged_df[col].astype(str))

# Normalize numeric columns
numeric_cols = merged_df.select_dtypes(include=['int64', 'float64']).columns.tolist()
scaler = MinMaxScaler()
merged_df[numeric_cols] = scaler.fit_transform(merged_df[numeric_cols])

# Feature selection using Logistic Regression with L1 penalty
X = merged_df.drop('attack', axis=1)
y = merged_df['attack']

model = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000)
model.fit(X, y)

selector = SelectFromModel(model, prefit=True)
X_embedded = selector.transform(X)

selected_features = X.columns[selector.get_support()]
print("Selected Features (Embedded method):", list(selected_features))

X_selected_df = pd.DataFrame(X_embedded, columns=selected_features)
# Out:
# <ipython-input-3-6d798b737715>:7: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('/content/reduced_data_1[1].csv')
# <ipython-input-3-6d798b737715>:8: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('/content/reduced_data_2[1].csv')
# <ipython-input-3-6d798b737715>:9: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df3 = pd.read_csv('/content/reduced_data_3[1].csv')
# <ipython-input-3-6d798b737715>:10: DtypeWarning: Columns (7,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4 = pd.read_csv('/content/reduced_data_4[1].csv')
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ...

# %%
# Embedded Feature Selection + Classification

from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from xgboost import XGBClassifier
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
# Ensure 'attack' is the target and exists in your DataFrame
X = merged_df.drop('attack', axis=1)
y = merged_df['attack']

# Embedded Feature Selection (Logistic Regression with L1 regularization)
model = LogisticRegression(penalty='l1', solver='liblinear', max_iter=1000)
model.fit(X, y)
# Out:
# LogisticRegression(max_iter=1000, penalty='l1', solver='liblinear')

# %%
# Select important features
selector = SelectFromModel(model, prefit=True)
X_embedded = selector.transform(X)
selected_features = X.columns[selector.get_support()]
X_selected_df = pd.DataFrame(X_embedded, columns=selected_features)

print("Selected Features using Embedded Method:", list(selected_features))

# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_selected_df, y, test_size=0.3, random_state=42)

# Define models
models = {
    "Logistic Regression": LogisticRegression(),
    "Random Forest": RandomForestClassifier(),
    "KNN": KNeighborsClassifier(),
    "SVM": SVC(),
    "XGBoost": XGBClassifier(use_label_encoder=False, eval_metric='mlogloss')
}

# Train and evaluate each model
for name, clf in models.items():
    clf.fit(X_train, y_train)
    y_pred = clf.predict(X_test)
    print(f"\n📌 Model: {name}")
    print(" Accuracy:", accuracy_score(y_test, y_pred))
    print(" Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
    print(" Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Selected Features using Embedded Method: ['pkSeqID', 'stime', 'flgs', 'proto', 'daddr', 'state', 'ltime', 'TnP_PerProto', 'N_IN_Conn_P_DstIP', 'category', 'subcategory']
#
# 📌 Model: Logistic Regression
#  Accuracy: 0.9998718830555801
#  Confusion Matrix:
#  [[      0     141]
#  [      0 1100416]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       141
#          1.0       1.00      1.00      1.00   1100416
#
#     accuracy                           1.00   1100557
#    macro avg       0.50      0.50      0.50   1100557
# weighted avg       1.00      1.00      1.00   1100557
#
#
# 📌 Model: Random Forest
#  Accuracy: 1.0
#  Confusion Matrix:
#  [[    141       0]
#  [      0 1100416]]
#  Classification Report:
#                precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00       141
#          1.0       1.00      1.00      1.00   1100416
#
# ...

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Step 1: Load the dataset
merged_df = pd.read_csv('/content/reduced_data_4[1].csv')  # <- Replace with your file path

# Step 2: Check for missing values (optional cleanup)
merged_df.dropna(inplace=True)  # Drops rows with missing values

# Step 3: Split features and labels
X = merged_df.drop(columns=['attack'])
y = merged_df['attack']

# Step 4: Encode any categorical columns in features
categorical_cols = X.select_dtypes(include=['object']).columns
if len(categorical_cols) > 0:
    X = pd.get_dummies(X, columns=categorical_cols)

# Step 5: Encode target if it's categorical
if y.dtype == 'object':
    le = LabelEncoder()
    y = le.fit_transform(y)

# Step 6: Feature selection using SelectKBest
selector = SelectKBest(score_func=f_classif, k=10)  # Select top 10 features
X_new = selector.fit_transform(X, y)

# Step 7: Get selected feature names
selected_features = X.columns[selector.get_support()].tolist()
print("Top 10 Selected Features:")
for i, feat in enumerate(selected_features, 1):
    print(f"{i}. {feat}")
# Out:
# Top 10 Selected Features:
# 1. flgs_eU
# 2. proto_udp
# 3. saddr_192.168.100.147
# 4. saddr_192.168.100.148
# 5. saddr_192.168.100.149
# 6. saddr_192.168.100.150
# 7. daddr_192.168.100.3
# 8. state_INT
# 9. category_DDoS
# 10. subcategory_UDP
# /usr/local/lib/python3.11/dist-packages/sklearn/feature_selection/_univariate_selection.py:107: RuntimeWarning: invalid value encountered in divide
#   msb = ssbn / float(dfbn)
